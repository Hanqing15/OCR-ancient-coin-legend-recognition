# %% [markdown]
# # OCR Metrics - CER and WER (Example Notebook)
#
# Example notebook for Medium article - Evaluating OCR Output with CER and WER
#
# *Highly recommended to run this notebook in Google Colab!*
#
# Link to article: https://towardsdatascience.com/evaluating-ocr-output-quality-with-character-error-rate-cer-and-word-error-rate-wer-853175297510
# Link to GitHub repo: https://github.com/Hanqing15/OCR-ancient-coin-legend-recognition.git
#
# Author: **YANG Hanqing**
#
# Referenced from author: **Kenneth Leung**

# %% [markdown]
# ___
# ## 1. Install and import necessary libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install pybind11
# !pip install fastwer
# !pip install pytesseract
# !sudo apt install tesseract-ocr
# !pip install pandas
# !pip install xrld
# !pip install openpyxl
# Out:
# Requirement already satisfied: pybind11 in d:\users\anaconda3\lib\site-packages (2.10.0)
#
# [notice] A new release of pip available: 22.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# Requirement already satisfied: fastwer in d:\users\anaconda3\lib\site-packages (0.1.3)
# Requirement already satisfied: pybind11 in d:\users\anaconda3\lib\site-packages (from fastwer) (2.10.0)
#
# [notice] A new release of pip available: 22.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# Requirement already satisfied: pytesseract in d:\users\anaconda3\lib\site-packages (0.3.9)
# Requirement already satisfied: Pillow>=8.0.0 in d:\users\anaconda3\lib\site-packages (from pytesseract) (9.1.1)
# Requirement already satisfied: packaging>=21.3 in d:\users\anaconda3\lib\site-packages (from pytesseract) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\users\anaconda3\lib\site-packages (from packaging>=21.3->pytesseract) (3.0.4)
#
# [notice] A new release of pip available: 22.2 -> 22.2.2
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# [notice] To update, run: python.exe -m pip install --upgrade pip
# 'sudo' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。
# Requirement already satisfied: pandas in d:\users\anaconda3\lib\site-packages (1.4.3)
# Requirement already satisfied: pytz>=2020.1 in d:\users\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\users\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in d:\users\anaconda3\lib\site-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in d:\users\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
#
# [notice] A new release of pip available: 22.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# [notice] A new release of pip available: 22.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement xrld (from versions: none)
# ERROR: No matching distribution found for xrld
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# Requirement already satisfied: openpyxl in d:\users\anaconda3\lib\site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in d:\users\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
#
# [notice] A new release of pip available: 22.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (d:\users\anaconda3\lib\site-packages)

# %%
import cv2
import pytesseract
import fastwer
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, display
import xlrd
import openpyxl
import sklearn

# %% [markdown]
# ___
# ## 2. Simple example of CER calculation

# %%
# Define reference text and output text
ref = "IMP CONSTANTINVS P F AVG "
output = ' IMP ab'
# Obtain Sentence-Level Character Error Rate (CER)
fastwer.score_sent(output, ref, char_level=True) # "True" refers to CER
# Out:
# 100.0

# %%
# Obtain Sentence-Level Word Error Rate (WER)
fastwer.score_sent(output, ref, char_level=False) # "True" refers to WER
# Out:
#   File "C:\Users\Ana\AppData\Local\Temp/ipykernel_16116/1126390725.py", line 2
#     fastwer.score_sent(output, ref，char_level=False) # "True" refers to WER
#                                   ^
# SyntaxError: invalid character '，' (U+FF0C)

# %% [markdown]
# ___
# ## 3. Read reference from excel

# %%
# Open workbook
file_path = r"C://Users//Ana//Desktop//ancient_monaie//Monnaies_copy.xlsx"
data = openpyxl.load_workbook(file_path)

# Choose the desiring sheet
sheet_monnaies = data.get_sheet_by_name("Monnaies_copy")
mintMark = data.get_sheet_by_name("mintMark")

# Getting legend_obverse from sheets
for i in range (2,863):
    print(sheet_monnaies.cell(row = i, column = 4).value)

# Getting legend_reverse from sheets
for i in range (2,863):
    print(sheet_monnaies.cell(row = i, column = 7).value)

# Getting mintMark from sheets
for i in range (2,796):
    print(mintMark.cell(row = i, column = 1).value)
# Out:
# D N MAXIMIANO FELICISSIMO SEN AVG
# I MP MAXIMIANVS AVG
# IMP MAXIMIANVS AV G
# DIVO CONSTANTIO PIO
# IMP MAXIMIANVS P F AVG
# CONSTANTINVS P F AVG
# IMP C CONSTANTIVS P F AVG
#
# IMP DIOCLETIANVS AVG
# IMP DIOCLETIANVS P F AVG
# CONSTANTIVS NOB CAES
# MAXIMIANVS NOB CAES
# IMP DIOCLETIANVS AVG
# IMP C CONSTANTINVS P F AVG
# IMP MAXIMIANVS P F AVG
# FL VAL CONSTANTI
# IMP MAXIMIANVS P F AVG
# GAL VAL MAXIMINVS NOBIL C
# IMP CONSTANTINVS P F AVG
# DIVO CONSTANTIO AVG
# D N MAXIMIANO BAEATISSIMO SEN AVG
# IMP MAXIMIANVS P F AVG
# IMP DIOCLETIANVS P F AVG
# CONSTANTIVS NOB C
# IMP C CONSTANTINVS P F AVG
# MAXIMIANVS NOB CAES
# IMP DIOCLETIANVS P F AVG
# CONSTANTIVS NOB CAES
# MAXIMIANVS NOBIL CAES
# MAXIMIANVS NOB CAES
# CONSTANTIVS NOB CAES
# IMP MAXIMIANVS P AVG
# FL VAL CONSTANTIVS NOB C
# IMP C MAXIMIANVS P F AVG
# IMP MAXIMIANVS AVG
# IMP C VAL MAXIMIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# MAXIMIANVS NOB CAES
# IMP DIOCLETIANVS P F AVG
# IMP MAXIMIANVS P AVG
# CONSTANTIVS NOB CAES
# IMP MAXIMIANVS AVG
# DIVO CONSTANTIO PIO
# IMP CONSTANTINVS P F AVG
# IMP MAXIMIANVS AVG
# IMP C MAXIMIANVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP C DIOCLETIANVS P F AVG
# IMP SEVERVS P F AVG
# CONSTANTIVS NOB CAES
# IMP C MAXENTIVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# MAXIMIANVS NOBIL C
# IMP MAXIMIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# IMP DIOCLETIANVS P AVG
# IMP C CONSTANTINVS P F AVG
# CONSTANTIVS NOB C
# D N DIOCLETIANO BEATISSIMO SEN AVG
# IMP DIOCLETIANVS P F AVG
# IMP C CONSTANTIVS P F AVG
# IMP MAXIMIANVS P F AVG
# CONSTANTIVS NOBIL C
# IMP MAXIMIANVS P F AVG
# CONSTANTIVS NOBIL C
# IMP DIOCLETIANVS P F AVG
# CONSTANTIVS NOB CAES
# FL VAL SEVERVS NOB C
# IMP C CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# MAXIMIANVS NOB CAES
# IMP CONSTANTIVS P F AVG
# MAXIMIANVS NOB CAES
# IMP MAXIMIANVS AVG
# DIVO CONSTANTIO PIO
# IMP C CONSTANTINVS P F AVG
# IMP CONSTANTINVS P AVG
# MAXIMIANVS NOB CAES
# MAXIMIANVS NOBIL C
# IMP MAXIMIANVS AVG
# DIVO CONSTANTIO PIO
# IMP C CONSTANTINVS P F AVG
# MAXIMIANVS NOB CAES
# CONSTANTIVS NOB CAES
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# GAL VAL MAXIMIANVS NOB C
# IMP DIOCLETIANVS P AVG
# IMP CONSTANTINVS P F AVG
# IMP MAXIMIANVS P AVG
# GAL VAL MAXIMINVS NOBIL C
# FL VAL CONSTANTIVS NOB C
# MAXIMIANVS NOB CAES
# IMP MAXIMIANVS AVG
# MAXIMINVS NOBILISSIMVS CAES
# IMP C CONSTANTIVS P F AVG
# MAXIMIANVS NOB C
# D N DIOCLETIANO P F S AVG
# IMP DIOCLETIANVS P F AVG
# CONSTANTIVS NOB CAES
# DIVO CONSTANTIO PIO
# IMP C VAL MAXIMIANVS P F AVG
# D N DIOCLETIANO FELICISSIMO SEN AVG
# MAXIMIANVS NOB CAES
# IMP DIOCLETIANVS AVG
# IMP C VAL MAXIMIANVS P F AVG
# CONSTANTIVS NOB CAES
# IMP DIOCLETIANVS AVG
# IMP C MAXIMIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# CONSTANTIVS NOB CAES
# IMP C VAL MAXIMIANVS P F AVG
# IMP DIOCLETIANVS AVG
# MAXIMIANVS NOBIL C
# IMP C DIOCLETIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# IMP C CONSTANTINVS P F AVG
# CONSTANTIVS NOB CAES
# CONSTANTIVS NOB CAES
# FL VAL CONSTANTIVS NOB C
# IMP DIOCLETIANVS P F AVG
# CONSTANTINVS NOB CAES
# IMP MAXIMIANVS P AVG
# IMP MAXIMIANVS P F AVG
# D N DIOCLETIANO BAEATISSIMO SEN AVG
# IMP MAXIMIANVS P F AVG
# IMP DIOCLETIANVS P F AVG
# FL VAL SEVERVS NOB C
# IMP C MAXIMIANVS P F AVG
# IMP DIOCLETIANVS AVG
# IMP C MAXENTIVS P F AVG
# CONSTANTIVS NOB C
# IMP C CONSTANTINVS P F AVG
# IMP DIOCLETIANVS P F AVG
# FL VAL CONSTANTIVS NOBIL C
# IMP MAXIMIANVS P F AVG
# CONSTANTIVS NOB C
# GAL VAL MAXIMINVS NOB C
# CONSTANTIVS NOB CAES
# IMP C CONSTANTINVS P F AVG
# DIVO CONSTANTIO PIO
# IMP MAXIMIANVS P F AVG
# CONSTANTIVS NOB CAES
# IMP DIOCLETIANVS AVG
# IMP C DIOCLETIANVS P F AVG
# DIVO CONSTANTIO PIO
# FL VAL CONSTANTINVS N C
# IMP C DIOCLETIANVS P F AVG
# IMP C VAL MAXIMIANVS P F AVG
# FL VAL CONSTANTINVS N C
# IMP MAXIMIANVS P F AVG
# MAXIMIANVS NOB CAES
# IMP C CONSTANTINVS P F AVG
# IMP C MAXIMIANVS P F AVG
# CONSTANTIVS NOB C
# IMP DIOCLETIANVS P F AVG
# MAXIMIANVS NOB CAES
# IMP MAXIMIANVS P F AVG
# IMP C VAL MAXIMIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# DIVO CONSTANTIO PIO
# IMP MAXIMIANVS P F AVG
# D N MAXIMIANO P F S AVG
# MAXIMIANVS NOB CAES
# CONSTANTIVS NOB C
# IMP DIOCLETIANVS AVG
# IMP C MAXIMIANVS P F AVGG
# IMP C VAL MAXIMIANVS P F AVG
# FL VAL CONSTANTINVS N C
# IMP DIOCLETIANVS AVG
# IMP DIOCLETIANVS P F AVG
# CONSTANTIVS NOB CAES
# MAXENTIVS P F AVG
# IMP C DIOCLETIANVS P F AVG
# IMP DIOCLETIANVS AVG
# IMP C MAXIMIANVS P F AVG
# MAXENTIVS P F AVG
# IMP MAXIMIANVS P F AVG
# IMP C CONSTANTIVS P F AVG
# CONSTANTIVS NOB CAES
# IMP CONSTANTIVS P F AVG
# IMP C CONSTANTIVS P F AVG
# FL VAL CONSTANTINVS NOB C
# D N MAXIMIANO BAEATISSIMO SEN AVG
# IMP MAXIMIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# IMP DIOCLETIANVS AVG
# CONSTANTIVS NOB C
# IMP MAXIMIANVS P AVG
# CONSTANTIVS NOB CAES
# MAXIMIANVS NOB CAES
# IMP MAXIMIANVS AVG
# IMP MAXIMIANVS P F AVG
# FL VAL CONSTANTIVS NOBIL C
# MAXIMIANVS NOB CAES
# CONSTANTIVS NOB CAES
# FL VAL CONSTANTINVS NOB C
# IMP CONSTANTINVS P F AVG
# IMP MAXIMIANVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP C CONSTANTINVS P F AVG
# IMP DIOCLETIANVS P F AVG
# FL VAL CONSTANTINVS NOB C
# IMP MAXIMIANVS P F AVG
# MAXIMINVS NOB CAES
# IMP CONSTANTIVS AVG
# IMP C DIOCLETIANVS P F AVG
# IMP C VAL MAXIMIANVS P F AVG
# IMP MAXIMIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP C DIOCLETIANVS P F AVG
# CONSTANTIVS NOB CAES
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP DIOCLETIANVS P F AVG
# D N MAXIMIANO FELICISSIMO SEN AVG
# D N MAXIMIANO BAEATISSIMO SEN AVG
# IMP C MAXIMIANVS P F AVG
# D N MAXIMIANO P F S AVG
#  IMIANO P F S AVG
# IMP C DIOCLETIANVS P F AVG
# FL VAL CONSTANTINVS NOB C
# IMP C M AVREL VAL MAXIMIANVS P F AVG
# FL VAL CONSTANTIVS N C
# IMP C CONSTANTINVS P F AVG
# GAL VAL MAXIMINVS NOB C
# IMP DIOCLETIANVS AVG
# MAXIMIANVS NOB CAES
# CONSTANTINVS P F AVG
# D N MAXIMIANO P F S AVG
# GAL VAL MAXIMINVS NOB C
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP DIOCLETIANVS P AVG
# IMP C VAL MAXIMIANVS P F AVG
# MAXIMINVS NOB CAESAR
# IMP DIOCLETIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP C MAXIMIANVS P F AVG
# MAXIMIANVS P F AVG
# CONSTANTIVS NOB C
# CONSTANTIVS NOB C
# GAL VAL MAXIMINVS NOB C
# IMP DIOCLETIANVS P F AVG
# IMP DIOCLETIANVS P AVG
# MAXENTIVS P F AVG
# GAL VAL MAXIMIANVS NOB CAES
# FL VAL CONSTANTINVS NOB C
# IMP C DIOCLETIANVS P F AVG
# FL VAL CONSTANTINVS NOB C
# IMP C DIOCLETIANVS P F AVG
# IMP C VAL MAXIMIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP C MAXIMIANVS P F AVG
# MAXIMIANVS NOBIL C
# FL VAL CONSTANTINVS N C
# IMP CONSTANTINVS P F AVG
# CONSTANTIVS NOB CAES
# IMP MAXIMIANVS AVG
# D N MAXIMIANO P F S AVG
# MAXIMIANVS NOB CAES
# IMP DIOCLETIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# MAXIMIANVS NOB CAES
# DIVO CONSTANTIO AVG
# IMP DIOCLETIANVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP DIOCLETIANVS AVG
# FL VAL CONSTANTIVS NOB C
# IMP C C VAL DIOCLETIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# MAXENTIVS P F AVG
# IMP DIOCLETIANVS P F AVG
# GAL VAL MAXIMINVS NOB C
# IMP CONSTANTINVS P F AVG
# DIVO CONSTANTIO PIO
# IMP DIOCLETIANVS P F AVG
# FL VAL CONSTANTINVS N C
# IMP DIOCLETIANVS P F AVG
# FL VAL CONSTANTINVS NOB C
# MAXIMIANVS NOB CAES
# D N DIOCLETIANO BAEATISSIMO SEN AVG
# IMP MAXIMIANVS AVG
# IMP C MAXIMIANVS P F AVG
# FL VAL CONSTANTINVS NOB C
# IMP C MAXIMIANVS P F AVG
# IMP C VAL MAXIMIANVS P F AVG
# IMP MAXIMIANVS P F AVG
# FL VAL CONSTANTINVS NOB C
# DIVO CONSTANTIO AVG
# IMP CONSTANTINVS P F AVG
# IMP C DIOCLETIANVS P F AVG
# FL VAL CONSTANTINVS NOB C
# IMP MAXIMIANVS P F AVG
# FL VAL CONSTANTINVS N C
# IMP C MAXIMIANVS P F AVG
# IMP C DIOCLETIANVS P F AVG
# IMP MAXIMIANVS P F AVG
# GAL VAL MAXIMINVS NOB C
# D N MAXIMIANO P F S AVG
# MAXIMIANVS NOB C
# IMP C DIOCLETIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP C DIOCLETIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# SEVERVS NOB C
# CONSTANTINVS P F AVG
# IMP C VAL MAXIMIANVS P F AVG
# CONSTANTIVS NOBIL C
# IMP C CONSTANTINVS P F AVG
# FL VAL SEVERVS NOB C
# IMP C C VAL DIOCLETIANVS P F AVG
# IMP MAXIMIANVS AVG
# IMP CONSTANTINVS P F AVG
# IMP DIOCLETIANVS P F AVG
# IMP MAXIMIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# CONSTANTINVS NOB CAES
# IMP C VAL MAXIMIANVS P F AVG
# IMP MAXIMIANVS AVG
# FL VAL CONSTANTINVS NOB C
# IMP MAXIMIANVS AVG
# CONSTANTIVS NOB CAES
# MAXIMIANVS NOB C
# CONSTANTIVS NOB   C
# IMP CONSTANTINVS P F AVG
# IMP MAXIMIANVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP MAXIMIANVS AVG
# IMP SEVERVS P F AVG
# CONSTANTIVS NOB C
# CONSTANTIVS NOB C
# CONSTANTIVS NOB CAES
# FL VAL CONSTANTINVS N C
# IMP DIOCLETIANVS P F AVG
# GAL VAL MAXIMINVS NOB CAES
# FL VAL CONSTANTINVS NOB C
# CONSTANTIVS NOBIL C
# MAXIMIANVS NOBIL C
# MAXIMIANVS NOB CAES
# CONSTANTINVS P F AVG
# GAL VAL MAXIMINVS NOB C
# IMP CONSTANTINVS P F AVG
# D N MAXIMIANO FELICISSIMO SEN AVG
# IMP DIOCLETIANVS AVG
# IMP C MAXIMIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# CONSTANTIVS NOB C
# MAXIMIANVS NOB CAES
# CONSTANTIVS NOB CAES
# MAXIMIANVS P F AVG
# IMP C DIOCLETIANVS P F AVG
# FL VAL SEVERVS NOB C
# MAXIMIANVS NOB CAES
# CONSTANTIVS NOB C
# IMP DIOCLETIANVS AVG
# IMP MAXIMIANVS P F AVG
# D N MAXIMIANO P F S AVG
# IMP MAXIMIANVS AVG
# IMP C VAL MAXIMIANVS P F AVG
# IMP DIOCLETIANVS AVG
# FL VAL CONSTANTINVS NOB C
# CONSTANTIVS NOB C
# DIVO CONSTANTIO PIO
# IMP C MAXIMIANVS P F AVG
# IMP MAXIMIANVS AVG
# CONSTANTINVS P F AVG
# FL VAL CONSTANTIVS NOB C
# GAL VAL MAXIMINVS NOB C
# FL VAL CONSTANTINVS NOBIL C
# IMP C M A MAXIMIANVS P F AVG
# D N DIOCLETIANO P F S AVG
# MAXIMIANVS NOB CAES
# CONSTANTIVS NOB CAES
# IMP CONSTANTINVS P F AVG
# IMP DIOCLETIANVS P F AVG
# IMP MAXIMIANVS P AVG
# IMP DIOCLETIANVS AVG
# IMP CONSTANTINVS P F AVG
# MAXIMIANVS NOB CAES
# MAXIMIANVS NOB CAES
# IMP CONSTANTINVS P F AVG
# MAXIMIANVS NOB CAES
# CONSTANTIVS NOB CAES
# MAXIMIANVS NOB CAES
# IMP DIOCLETIANVS P F AVG
# IMP C MAXIMIANVS P FEL AVG
# MAXIMIANVS NOBIL C
# IMP MAXIMIANVS P F AVG
# IMP C VAL MAXIMIANVS P F AVG
# IMP DIOCLETIANVS P F AVG
# CONSTANTIVS NOB CAES
# CONSTANTIVS NOB CAES
# IMP C CONSTANTINVS P F AVG
# DIVO CONSTANTIO PIO
# GAL VAL MAXIMINVS NOB C
# FL VAL CONSTANTIVS NOB CAES
# IMP C DIOCLETIANVS P F AVG
# IMP C VAL MAXIMIANVS P F AVG
# DIVO CONSTANTIO AVG
# IMP CONSTANTINVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# DIVO CONSTANTIO PIO
# CONSTANTIVS NOB CAES
# MAXIMIANVS NOB CAES
# DIVO CONSTANTIO PIO
# IMP CONSTANTINVS P F AVG
# IMP C DIOCLETIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# MAXIMIANVS NOB CAES
# IMP CONSTANTINVS AVG
# MAXIMIANVS NOB CAES
# MAXIMIANVS NOBIL C
# SEVERVS NOB CAESAR
# IMP C CONSTANTINVS P F AVG
# IMP C SEVERVS P F AVG
# IMP C VAL MAXIMIANVS P F AVG
# IMP CONSTANTINVS P F AVG
# CONSTANTIVS NOB CAES
# IMP C MAXIMIANVS P F AVG
# IMP MAXIMIANVS AVG
# GAL VAL MAXIMINVS NOB C
# IMP CONSTANTINVS P F AVG
# D N MAXIMIANO FELICISSIMO SEN AVG
# SEVERVS NOBILISSIMVS C
# IMP CONSTANTINVS P F AVG
# FL VAL CONSTANTIVS NOB C
# IMP C CONSTANTINVS P F AVG
# MAXIMIANVS NOB   C
# MAXIMIANVS NOB CAES
# MAXIMIANVS NOBIL C
# IMP DIOCLETIANVS AVG
# FL VAL CONSTANTINVS NOB C
# IMP C CONSTANTINVS P F AVG
# IMP C CONSTANTINVS P F AVG
# CONSTANTINVS P F AVG
# IMP MAXIMIANVS AVG
# IMP C CONSTANTIVS P F AVG
# CONSTANTIVS NOB CAES
# IMP C CONSTANTINVS P F AVG
# CONSTANTIVS NOB CAES
# IMP DIOCLETIANVS AVG
# D N DIOCLETIANO FELICISSIMO SEN AVG
# MAXIMIANVS NOB CAES
# FL VAL CONSTANTINVS NOB C
# D N MAXIMIANO FELICISSIMO SEN AVG
# IMP MAXIMIANVS P F AVG
# IMP CONSTANTINVS P F AVG
# CONSTANTIVS NOB CAES
# MAXIMIANVS NOB CAES
# IMP C DIOCLETIANVS P F AVG
# IMP DIOCLETIANVS P F AVG
# D N MAXIMIANO BAEATISSIMO SEN AVG
# FL VAL CONSTANTINVS NOB C
# CONSTANTIVS NOBIL C
# IMP C MAXIMIANVS P F AVG
# MAXIMIANVS NOB CAES
# MAXIMIANVS NOBIL C
# IMP C VAL MAXIMIANVS P F AVG
# IMP C CONSTANTIVS P F AVG
# IMP DIOCLETIANVS P AVG
# IMP DIOCLETIANVS P AVG
# IMP C CONSTANTINVS P F AVG
# IMP C CONSTANTINVS P F AVG
# FL VAL CONSTANTINVS N C
# IMP CONSTANTIVS AVG
# MAXIMIANVS NOB CAES
# MAXIMIANVS NOB CAES
# FL VAL CONSTANTIVS NOB C
# IMP MAXIMIANVS P F AVG
# FL VAL CONSTANTIVS NOB CAES
# GAL VAL MAXIMINVS NOB C
# CONSTANTINVS NOB CAES
# FL VAL CONSTANTIVS NOB C
# MAXIMIANVS NOB CAES
# IMP CONSTANTIVS AVG
# IMP C MAXIMIANVS P F AVG
# IMP CONSTANTIVS P F AVG
# IMP CONSTANTIVS AVG
# IMP C MAXIMIANVS P F AVG
# MAXIMIANVS NOB CAES
# SEVERVS NOB C
# FL VAL CONSTANTINVS NOB C
# IMP DIOCLETIANVS P F AVG
# FL VAL CONSTANTINVS N C
# MAXIMIANVS NOB CAES
# CONSTANTINVS NOB CAES
# MAXIMIANVS NOB CAES
# CONSTANTIVS NOBIL C
# IMP C DIOCLETIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# MAXIMIANVS NOBIL C
# IMP C MAXIMIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# IMP C VAL MAXIMIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP C CONSTANTINVS P F AVG
# SEVERVS NOB CAES
#
# IMP MAXIMIANVS P F AVG
# IMP MAXIMIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# CONSTANTIVS NOB CAES
# IMP C MAXIMIANVS P F AVG
# SEVERVS NOB CAESAR
# D N DIOCLETIANO FELICISSIMO SEN AVG
# CONSTANTIVS NOB CAES
# IMP CONSTANTINVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP C VAL MAXIMIANVS P F AVG
# IMP MAXIMIANVS P F AVG
# IMP DIOCLETIANVS AVG
# CONSTANTIVS NOB C
# IMP DIOCLETIANVS AVG
# IMP C CONSTANTINVS P F AVG
# IMP C DIOCLETIANVS P F AVG
# IMP DIOCLETIANVS P AVG
# CONSTANTIVS NOB CAES
# IMP C MA AVG
# GAL VAL MAXIMINVS NOB C
# IMP C DIOCLETIANVS P F AVG
# FL VAL CONSTANTINVS N C
# IMP DIOCLETIANVS P F AVG
# CONSTANTIVS NOB C
# IMP CONSTANTINVS P F AVG
# D N MAXIMIANO FELICISSIMO SEN AVG
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# FL VAL CONSTANTINVS NOB C
# IMP DIOCLETIANVS P F AVG
# FL VAL CONSTANTINVS NOB C
# D N MAXIMIANO P F S AVG
# CONSTANTINVS P F AVG
# IMP C CONSTANTINVS P F AVG
# CONSTAN[
# IMP MAXIMIANVS P F AVG
#
# MAXIMIANVS NOB CAES
# IMP MAXIMIANVS P F AVG
# MAXIMIANVS NOB CAES
# D N DIOCLETIANO P F S AVG
# IMP DIOCLETIANVS AVG
# DIVO CONSTANTIO AVG
# CONSTANTINVS P F AVG
# IMP DIOCLETIANVS P AVG
# CONSTANTIVS NOB CAES
# IMP CONSTANTINVS P F AVG
# COR SA[lonina aug]
# IMP LI CINIVS AVG
# CRISP
# IMP C DIOCLETIANVS P F AVG
# IMP MAXIMIANVS P F AVG
# MAXIMIANVS NOB CAES
# IMP C VAL MAXIMIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# CONSTANTIVS NOB CAES
# IMP DIOCLETIANVS P F AVG
# MAXIMIANVS NOB CAES
# DIVO CONSTANTIO PIO
# IMP DIOCLETIANVS AVG
# CONSTANTIVS NOB CAES
# IMP CONSTANTINVS P F AVG
# IMP C CONSTANTINVS P F AVG
# D N MAXIMIANO FELICISSIMO SEN AVG
# CONSTANTIVS NOB CAES
# IMP CONSTANTIVS AVG
# IMP CONSTANTINVS P F AVG
# CONSTANTIVS NOBIL C
# MAXIMIANVS NOB C
# IMP MAXIMIANVS P F AVG
# MAXIMIANVS NOB CAES
# IMP C MAXIMIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# FL VAL CONSTANTINVS NOB C
# IMP C SEVERVS P F AVG
# MAXIMIANVS NOB CAES
# CONSTANTIVS NOB CAES
# IMP C VAL MAXIMIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# MAXIMIANVS NOB CAES
# IMP C CONSTANTINVS P F AVG
# IMP C CONSTANTINVS P F AVG
# IMP C MAXIMIANVS AVG
# CONSTANTIVS NOB   C
# CONSTANTINVS NOB CAES
# IMP C CONSTANTINVS P F AVG
# CONSTANTIVS NOB C
# D N MAXIMIANO P F S AVG
# IMP C MAXIMIANVS P FEL AVG
# FL VAL CONSTANTINVS NOB C
# IMP C M A MAXIMIANVS P F AVG
# DIVO CONSTANTIO AVG
# CONSTANTIVS NOB C
# IMP C VAL MAXIMIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP MAXIMIANVS IVN AVG
# MAXIMIANVS NOB CAES
# MAXIMIANVS NOBIL C
# IMP C VAL MAXIMIANVS P F AVG
# MAXIMIANVS NOB CAES
# CONSTANTIVS NOB CAES
# IMP C MAXIMIANVS P AVG
# FL VAL CONSTANTINVS N C
# CONSTANTIVS NOB C
# GAL VAL MAXIMINVS NOB C
# D N DIOCLETIANO P F S AVG
# IMP C CONSTANTINVS P F AVG
# CONSTANTIVS NOB CAES
# CONSTANTINVS NOB CAES
# IMP C MAXIMIANVS P F AVG
# D N DIOCLETIANO P F S AVG
# CONSTANTINVS P F AVG
# IMP C M A MAXIMIANVS P F AVG
# CONSTANTIVS NOB CAES
# IMP C CONSTANTINVS P F AVG
# CONSTANTIVS NOB C
# IMP C CONSTANTINVS P F AVG
# IMP DIOCLETIANVS AVG
# IMP C MAXIMIANVS P F AVG
# IMP MAXIMIANVS P F AVG
# DIVO CONSTANTIO AVG
# IMP C MAXIMIANVS P F AVG
# IMP C DIOCLETIANVS P F AVG
# IMP DIOCLETIANVS AVG
# IMP C CONSTANTINVS P F AVG
# FL VAL CONSTANTINVS NOB C
# CONSTANTIVS NOBIL C
# G VAL MAXIMIANVS NOB C
# IMP C CONSTANTINVS P F AVG
# IMP SEVERVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP C CONSTANTINVS P F AVG
# IMP C VAL MAXIMIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP DIOCLETIANVS AVG
# D N DIOCLETIANO P F S AVG
# FL VAL CONSTANTINVS N C
# IMP C CONSTANTINVS P F AVG
# CONSTANTINVS NOB CAES
# MAXIMIANVS NOB CAES
# MAXIMIANVS NOB C
# MAXIMIANVS NOB CAES
# GAL VAL MAXIMINVS NOB C
# IMP MAXIMIANVS AVG
# IMP C CONSTANTINVS P F AVG
# IMP DIOCLETIANVS AVG
# IMP MAXIMIANVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS AVG
# IMP CONSTANTIVS AVG
# IMP C DIOCLETIANVS P F AVG
# MAXIMIANVS NOBIL C
# CONSTANTIVS NOB CAES
#
# D N DIOCLETIANO FELICISSIMO SEN AVG
# CONSTANTIVS NOB C
# D N DIOCLETIANO P F S AVG
# FL VAL CONSTANTINVS NOB C
# IMP CONSTANTIVS AVG
# IMP MAXIMIANVS P AVG
# IMP MAXIMIANVS P AVG
# IMP C VAL MAXIMIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# MAXENTIVS P F AVG
# CONSTANTIVS NOB C
# IMP C DIOCLETIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP DIOCLETIANVS AVG
# IMP C CONSTANTINVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP MAXIMIANVS AVG
# IMP C DIOCLETIANVS P F AVG
# IMP DIOCLETIANVS AVG
# IMP C DIOCLETIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# CONSTANTIVS NOB CAES
# FL VAL CONSTANTIVS N C
# MAXIMIANVS NOB CAES
# IMP DIOCLETIANVS P F AVG
# FL VAL CONSTANTINVS N C
# CONSTANTINVS NOB CAES
# D N MAXIMIANO P F S AVG
# IMP CONSTANTINVS P F AVG
# IMP C CONSTANTINVS P F AVG
# IMP C MAXIMIANVS P F AVG
# MAXIMIANVS NOBIL C
# IMP CONSTANTINVS P F AVG
# FL VAL CONSTANTINVS NOB C
# IMP C MAXIMIANVS P F AVG
# IMP MAXIMIANVS P F AVG
# GAL VAL MAXIMINVS N C
# FL VAL CONSTANTINVS NOBIL C
# IMP C DIOCLETIANVS P F AVG
# IMP C VAL MAXIMIANVS P F AVG
# IMP DIOCLETIANVS P F AVG
# IMP MAXIMIANVS P AVG
# DIVO CONSTANTIO PIO
# CONSTANTINVS NOB CAES
# IMP CONSTANTINVS P F AVG
# CONSTANTIVS NOB C
# IMP DIOCLETIANVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP DIOCLETIANVS P AVG
# IMP CONSTANTINVS P F AVG
# IMP C DIOCLETIANVS P F AVG
# FL VAL CONSTANTINVS NOB C
# D N DIOCLETIANO BEATISSIMO SEN AVG
# IMP C MAXIMIANVS P F AVG
# CONSTANTIVS NOB CAES
# IMP MAXIMIANVS P F AVG
# IMP DIOCLETIANVS AVG
# IMP MAXIMIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# DIVO CONSTANTIO AVG
# IMP MAXIMIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP DIOCLETIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# MAXENTIVS P F AVG
# IMP CONSTANTINVS AVG
# IMP CONSTANTINVS P F AVG
# IMP DIOCLETIANVS AVG
# IMP DIOCLETIANVS AVG
# IMP C MAXIMIANVS P F AVG
# IMP C DIOCLETIANVS P F AVG
# FL VAL CONSTANTINVS NOB C
# D N DIOCLETIANO FELICISSIMO SEN AVG
# IMP DIOCLETIANVS AVG
# MAXIMIANVS NOB CAES
# IMP DIOCLETIANVS AVG
# IMP MAXIMIANVS AVG
# IMP MAXIMIANVS P F AVG
# DIVO CONSTANTIO PIO
# IMP C DIOCLETIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# MAXIMINVS NOBILIS C
# IMP C MAXIMIANVS P F AVG
# FL VAL CONSTANTINVS NOB C
# DIVO CONSTANTIO PIO
# IMP C VAL MAXIMIANVS P F AVG
# IMP DIOCLETIANVS AVG
# MAXIMIANVS NOB CAES
# D N MAXIMIANO P F S AVG
# IMP C CONSTANTINVS P F AVG
# FL VAL CONSTANTINVS NOB C
# IMP C DIOCLETIANVS P F AVG
# IMP DIOCLETIANVS P F AVG
# MAXIMIANVS NOB CAES
# MAXIMINVS NOB CAESAR
# MAXIMIANVS NOB C
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP C DIOCLETIANVS P F AVG
# DIVO CONSTANTIO PIO
# IMP C MAXIMIANVS P F AVG
# IMP DIOCLETIANVS P F AVG
# SEVERVS NOB CAESAR
# GAL VAL MAXIMINVS NOBIL C
# CONSTANTIVS NOB CAES
# MAXIMIANVS NOB CAES
# FL VAL CONSTANTINVS N C
# IMP C DIOCLETIANVS P F AVG
# IMP MAXIMIANVS P F AVG
# IMP C CONSTANTINVS P F AVG
# FL VAL CONSTANTINVS N C
# MAXENTIVS P F AVG
# IMP C CONSTANTIVS P F AVG
# IMP MAXIMIANVS P F AVG
# CONSTANTINVS P F AVG
# IMP C CONSTANTINVS P F AVG
# IMP MAXIMIANVS P F AVG
# IMP C MAXIMIANVS P F AVG
# FL VAL CONSTANTINVS NOB C
# IMP MAXIMIANVS P F AVG
# IMP MAXIMIANVS P F AVG
# CONSTANTIVS NOB C
# IMP C MAXIMIANVS P F AVG
# IMP DIOCLETIANVS P AVG
# FL VAL CONSTANTIVS N C
# IMP CONSTANTIVS AVG
# CONSTANTIVS NOB CAES
# FL VAL CONSTANTINVS NOB C
# GAL VAL MAXIMINVS NOB C
# CONSTANTIVS NOB CAES
# FL VAL SEVERVS NOB CAES
# GAL VAL MAXIMINVS NOB CAES
# IMP DIOCLETIANVS P AVG
# IMP CONSTANTINVS P F AVG
# IMP MAXIMIANVS P F AVG
# CONSTANTIVS NOB CAES
# CONSTANTIVS NOB C
# IMP C CONSTANTINVS P F AVG
# FL VAL SEVERVS NOB C
# IMP C MAXIMIANVS P F AVG
# IMP C VAL MAXIMIANVS P F AVG
# CONSTANTIVS NOBIL C
# IMP DIOCLETIANVS P AVG
# GAL VAL MAXIMINVS NOB C
# MAXIMIANVS NOB CAES
# SEVERVS NOB CAESAR
# IMP C MAXIMIANVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP C MAXIMIANVS P F AVG
# IMP MAXIMIANVS AVG
# D N MAXIMIANO P F S AVG
# IMP DIOCLETIANVS P F AVG
# D N MAXIMIANO P F S AVG
# IMP DIOCLETIANVS P F AVG
# CONSTANTIVS NOB C
# CONSTANTIVS NOB CAES
# GAL VAL MAXIMINVS NOB CAES
# D N MAXIMIANO FELICISSIMO SEN AVG
# IMP MAXIMIANVS P F AVG
# IMP MAXIMIANVS P F AVG
# MAXIMIANVS NOB CAES
# IMP CONSTANTINVS P F AVG
# IMP DIOCLETIANVS P F AVG
# CONSTANTIVS NOB C
# IMP C MAXIMIANVS P F AVG
# FL VAL CONSTANTINVS NOB C
# CONSTANTIVS NOB CAES
# IMP MAXIMIANVS AVG
# FL VAL CONSTANTINVS N C
# D N MAXIMIANO P F S AVG
# IMP C CONSTANTINVS P F AVG
# CONSTANTIVS NOB CAES
# CONSTANTIVS NOB C
# FL VAL CONSTANTINVS NOB C
# IMP CONSTANTINVS P F AVG
# IMP C MAXENTIVS P F AVG
# IMP MAXIMIANVS AVG
# DIVO CONSTANTIO PIO
# IMP C MAXIMIANVS P F AVG
# G VAL MAXIMIANVS NOB C
# G VAL MAXIMIANVS CAES
# FL VAL CONSTANTINVS NOB C
# MAXIMIANVS NOB CAES
# IMP CONSTANTINVS P F AVG
# IMP CONSTANTINVS P F AVG
# IMP C DIOCLETIANVS P F AVG
# PROVIDENTIA DEORVM QVIES AVGG
# GENIO POP VLI ROMANI
# GENIO POP VLI ROMANI
# MEMORIA FELIX
# SALVIS AVGG ET CAESS FEL KART
# SOLI INVIC TO COMITI
# FIDES   M I LITVM
#
# GENIO POP VLI ROMANI
# SACRA MONET AVGG ET CAESS NOSTR
# SALVIS AVGG ET CAESS AVCTA KART
# SALVIS AVGG ET CAESS AVCTA KART
# GENIO POPV LI ROMANI
# CONSTANTINO   P   AVG B R P NAT
# GENIO   POP ROM
# M AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# SOLI INVIC TO COMITI
# MEMORIA DIV I CONSTANTI
# PROVIDENTIA DEORVM QVIES AVGG
# SALVIS AVGG ET CAESS FEL KART
# FELIX ADV ENT AVGG NN
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO POPV LI   ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# SAC MON VRB AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# PAX   A VGG
# GENIO   POP ROM
# SACRA MONET AVGG ET CAESS NOSTR
# SAC MON VRB AVGG ET CAESS NN
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# MEMORIA FELIX
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# PRINCIPI   IV VENTVTIS
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# SACRA MONET AVGG ET CAESS NOSTR
# CONSERV   VRB SVAE
# CONSERVATORES VRB SVAE
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# PROVIDENTIA DEORVM QVIES AVGG
# GENIO POPV LI ROMANI
# FIDES   M I LITVM
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# SAC MON VRB AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# PRINCIPI   I V VENTVTIS
# MARTI PATRI PROPVGNATORI
# GENIO POP VLI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# SACRA MON VRB AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# MEMORIA FELIX
# GENIO   POP ROM
# PRINCIPI IV VE NTVTIS
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# MEMORIA FELIX
# GENIO   POP ROM
# SACRA MONET AVGG ET CAESS NOSTR
# SALVIS AVGG ET CAESS FEL KART
# SOLI INVIC TO COMITI
# PRINCIPI IVVENTVTIS
# MONETA .S. AV G.G ET CAESS NN
# GENIO POPV LI ROMANI
# SOLI INVIC TO COMITI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# VOTX
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# FIDES   M I LITVM
# GENIO POPV LI ROMANI
# QVIES AV GSTORVM
# SACR MONET AVGG ET CAESS NOSTR
# GENIO POPV LI ROMANI
# MEMORIA FELIX
# GENIO   POP ROM
# PROVIDENTIA DEORVM QVIES AVGG
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# TEMPORVM   FELICITAS
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# FIDES   M I LITVM
# SALVIS AVGG ET CAESS FEL KART
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# SACRA MON VRB AVGG ET CAESS NN
# GENIO   POP ROM
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# SAC MON VRB AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# FELIX ADV ENT AVGG NN
# VIRTVS AV GG ET CAESS NN
# GENIO POP [uli ro]MANI
# FELIX ADVENT AVGG NN
# PROVIDENTIA DEORVM QVIES AVGG
# GENIO   POP ROM
# FORTVNAE RE DVCI CAESS NN
# GENIO POPV LI ROMANI
# CONSERV   VRB SVAE
# GENIO POPV LI ROMANI
# CONSERV   VRB SVAE
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# M SACRA AVGG ET CAESS NN
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# MEMORIA FELIX
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# MEMORIA FELIX
# GENIO   POP ROM
# SAC MON VRB AVGG ET CAESS NN
# GENIO   POP ROM
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO   POP ROM
# SACRA MON VRB AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# FELIX A D VENT AVGG NN
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# GENIO POPVLI ROMANI
# MEMORIA FELIX
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# SACRA MONET AVGG   ET CAESS NOSTR
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# CONSERVATO RES VRB SVAE
# GENIO   POP ROM
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# FORTVNAE REDVCI CAESS NN
# SAC MON VRB AVGG ET CAESS NN
# CONSERV   VRB SVAE
# SAC MON VRB AVGG ET CAESS NN
# GENIO POP VLI ROMANI
# SACRA MONET AVGG ET CAESS NOSTR
# CONSERVATORES VRB SVAE
# SALVIS AVGG ET CAESS FEL KART
# FIDES   M I LITVM
# SAC MON VRB AVGG ET CAESS NN
# VIRTVS AV GG ET CAESS NN
# FIDES   M I LITVM
# GENIO POP VLI ROMANI
# PROVIDENTIA DEORVM QVIES AVGG
# FIDES MILITVM AVGG ET CAESS NN
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# MONETA S AVGG ET CAESS NN
# FELIX A D VENT AVGG NN
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# SOLI INVIC TO COMITI
# GENIO POPV LI ROMANI
# SOLI INVIC TO COMITI
# SOLI INVIC TO COMITI
# SOLI INVIC TO COMITI
# SOLI INVIC TO COMITI
# SOLI INVIC TO COMITI
# PRINCIPI   I V VENTVTIS
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# SAC MON VRB AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV LI ROMANI
# S M VRB AVGG ET CAESS NN
# SACRA MONET AVGG   ET CAESS NOSTR
# SOLI INVIC TO COMITI
# SOLI INVIC TO COMITI
# GENIO POPV LI ROMANI
# PROVIDENTIA DEORVM QVIES AVGG
# PROVIDENTIA DEORVM QVIES AVGG
# GENIO POPV LI ROMANI
# GENIO   POP ROM
#  NIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# MONETA S AVGG ET CAESS NN
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# SOLI INVIC TO COMITI
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# SOLI INVIC TO COMITI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# VIRTVS AVGG ET CAESS NN
# SALVIS AVGG ET CAESS FEL KART
# GENIO   POP ROM
# SOLI INVIC TO COMITI
# SACRA MONET AVGG ET CAESS NOSTR
# QVIES AVG
# GENIO POP VLI ROMANI
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV LI ROMANI
# CONSERVATORES VRB SVAE
# GENIO POPV L I ROMANI
# MARTI PATRI P ROPVGNATORI
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO   POP ROM
# SACRA MON VRB AVGG ET CAESS NN
# GENIO   POP ROM
# GENIO   POP ROM
# SOLI INVIC TO COMITI
# FIDES   M I LITVM
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# SALVIS AVGG ET CAESS FEL KART
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# SALVIS AVGG ET CAESS FEL KART
# MEM DIVI   CONSTANTI
# SALVIS AVGG ET CAESS FEL KART
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# FIDES   M I LITVM
# CONSERV   VRB SVAE
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV LI ROMANI
# SOLI INVIC TO COMITI
# MEMORIA FELIX
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# PRINCIPI   IVVE NTVTIS
# GENIO POP VLI ROMANI
# PROVIDENTIA DEORVM QVIES AVGG
# GENIO POP VLI ROMANI
# VIRTVS AV GG ET CAESS NN
# MARTI PATRI P ROPVGNATORI
# FIDES   M I LITVM
# GENIO   POP ROM
# SALVIS AVGG ET CAESS FEL KART
# MARTI PATRI PROPVGNATORI
# CONSECRATIO
# SOLI INVIC TO COMITI
# GENIO POP VLI ROMANI
# PRINCIPI   IV VENTVTIS
# GENIO POP VLI ROMANI
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# SACRA MONET AVGG   ET CAESS NOSTR
# SACRA MON VRB AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# MARTI CON SERVATORI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# MARTI PA TRI PROPVG
# FELIX ADV ENT AVGG NN
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# VIRTVS AV GG ET CAESS NN
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# MARTI PATRI P ROPVGNATORI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# PRINCIPI   IVVE NTVTIS
# GENIO POPV LI ROMANI
# SOLI INVIC TO COMITI
# MARTI CO NSERVATORI
# GENIO POP VLI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# SACRA MON VRB AVGG ET CAESS NN
# GENIO   POP ROM
# SALVIS AVGG ET CAESS FEL KART
# SALVIS AVGG ET CAESS FEL KART
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# SOLI INVIC TO COMITI
# GENIO POPV LI ROMANI
# MARTI CO NSERVATORI
# PROVIDENTIA DEORVM QVIES AVGG
# GENIO POPV LI ROMANI
# FIDES   M I LITVM
# PRINCIPI   IV VENTVTIS
# GENIO POPV LI ROMANI
# S M VRB AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# QVIES AVG
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# SAC MON VRB AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# MARTI PATRI CONSERVATORI
# GENIO POPV LI ROMANI
# MEMORIA FELIX
# SACRA MON VRB AVGG ET CAESS NN
# GENIO POP VLI ROMANI
# CONSERV   VRB SVAE
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# QVIES AV GVSTORVM
# SACRA MONET AVGG   ET CAESS NOSTR
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# MARTI PATRI PROPVGNATORI
# SALVIS AVGG ET CAESS FEL KART
# SALVIS AVGG ET CAESS FEL KART
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV LI ROMANI
# SAC MON VRB AVGG ET CAESS NN
# PRINCIPI IV VENT B R P NAT
# MEMORIA FELIX
# GENIO POPV LI ROMANI
# GENIO POPV L I ROMANI
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# MEMORIA DIV I CONSTANTI
# SOLI INVIC TO COMITI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# MEMORIA FELIX
# GENIO POP VLI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# MEMORIA FELIX
# SOLI INVIC TO COMITI
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO   POP ROM
# SACRA MONET AVGG ET CAESS NOSTR
# CONSERV   VRB SVAE
# GENIO POPV LI ROMANI
# MARTI CON SERVATORI
# SAC MON VRB AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# VIRTVS AV GG ET CAESS NN
# GENIO   POP ROM
# VIRTVS AV GG ET CAESS NN
# GENIO   POP ROM
# MARTI PATRI CONSERVATORI
# SALVIS AVGG ET CAESS FEL KART
# SAC MON VRB AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# SOLI INVIC TO COMITI
# PROVIDENTIA DEORVM QVIES AVGG
# GENIO POPV LI ROMANI
# SOLI INVIC TO COMITI
# M SACRA AV GG ET CAESS NN
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# MARTI PATRI CONSERVATORI
# GENIO   POP ROM
# GENIO   POP ROM
# SOLI INVIC TO COMITI
# GENIO POP VLI ROMANI
# FIDES MI LITVM
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# PROVIDENTIA DEORVM QVIES AVGG
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# PROVIDENTIA DEORVM QVIES AVGG
# SALVIS AVGG ET CAESS FEL KART
# SOLI INVIC TO COMITI
# GENIO POPV LI ROMANI
# SAC MON VRB AVGG ET CAESS NN
# SACRA MONET AVGG   ET CAESS NOSTR
# GENIO POPV LI ROMANI
# PROVIDENTIA DEORVM QVIES AVGG
# MARTI PATRI CONSERVATORI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# SAC MON VRB AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# MARTI PATRI PROPVGNATORI
# GENIO   POP ROM
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# VIRTVS AV GG ET CAESS NN
# GENIO POP VLI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# FELIX A D VENT AVGG NN
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# VIRTVS AV GG ET CAESS NN
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# CONSERV   VRB SVAE
# GENIO   POP ROM
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# SOLI INVIC TO COMITI
# MARTI PATRI CONSERVATORI
# VIRTVS AV GG ET CAESS NN
#
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# SAC MON VRB AVGG ET CAESS NN
# VIRTVS AVGG ET CAESS NN
# PROVIDENTIA DEORVM QVIES AVGG
# SACRA MONET AVGG   ET CAESS NOSTR
# MARTI PATRI CONSERVATORI
# FIDES   M I LITVM
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# SACRA MONET AVGG   ET CAESS NOSTR
# MONETA SACRA AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# GENIO POP VLI ROM
# GENIO   POP ROM
# SACRA MON VRB AVGG ET CAESS NN
# GENIO   POP ROM
# SALVIS AVGG ET CAESS AVCTA KART
# GENIO POPV LI ROMANI
# MARTI PATRI PROPVGNATORI
# PROVIDENTIA DEORVM QVIES AVGG
# MARTI PATRI CONSERVATORI
# MARTI PATRI PROPVGNATORI
# GENIO POP V LI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# GENIO   POP ROM
# GENIO   POP ROM
# VIRTVS PER PETVA AVG
# GENIO   POP ROM
# SACRA MON VRB [AVGG ET CAESS NN]
# SALVIS AVGG ET CAESS FEL KART
#
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# SAC MON VRB AVGG ET CAESS NN
# QVIES AV GVSTORVM
# GENIO POP V LI ROMANI
# MEMORIA DIV I CONSTANTI
# CONSERV   VRB SVAE
# MONETA S AVGG ET CAESS NN
# SACRA MONET AVGG ET CAESS NOSTR
# SOLI INVIC TO COMITI
# [fecundit]AS AVG
# VIRTVS   EXERCIT VOT / XX
#  VOT / IS / XX
# GENIO POPVLI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# SACRA MONET AVGG   ET CAESS NOSTR
# GENIO POPV LI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV LI ROMANI
# MEMORIA FELIX
# GENIO POPV LI ROMANI
# SACRA MONET AVGG ET CAESS NOSTR
# MARTI PATRI PROPVGNATORI
# PRINCIPI   I V VENTVTIS
# PROVIDENTIA DEORVM QVIES AVGG
# SACRA MONET AVGG   ET CAESS NOSTR
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV LI ROMANI
# FIDES   M I LITVM
# PRINCIPI   IV VENTVTIS
# GENIO   POP ROM
# FIDES   M I LITVM
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# GENIO   POP ROM
# SACRA MON VRB AVGG ET CAESS NN
# MARTI PATRI CONSERVATORI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# VIRTVS AV GG ET CAESS NN
# GENIO   P OP ROM
# GENIO POP VLI ROMANI
# GENIO   P OP ROM
# GENIO POPV LI ROMANI
# MARTI PATRI CONSERVATORI
# GENIO POP VLI ROMANI
# CONSECRATIO
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# MARTI PATRI PROPVGNATORI
# SAC MON VRB AVGG ET CAESS NN
# TEMPORVM   FELICITAS
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# QVIES AVG V STORVM
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# SAC MON VRB AVGG ET CAESS NN
# GENIO POP VLI ROMANI
# QVIES AVG V STORVM
# SOLI INVIC TO COMITI
# GENIO POPV LI ROMANI
# SAC MON VRB AVGG ET CAESS NN
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# SACRA MONET AVGG   ET CAESS NOSTR
#  MONETA S AVGG ET CAESS NN
# MEM DIVI   CONSTANTI
# FIDES MI LITVM
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# PRINCIPI IV VE NT B R P NAT
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# MARTI PATRI CONSERVATORI
# SOLI INV IC TO COMITI
# SOLI INVIC TO COMITI
# PRINCIPI   IVVE NTVTIS
# GENIO   POP ROM
# CONSERV   VRB SVAE
# GENIO POP VLI ROMANI
# QVIES AV G V STORVM
# GENIO   P OP ROM
# GENIO   POP ROM
# VIRTVS AV GG ET CAESS NN
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO POP VLI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# MARTI PATRI CONSERVATORI
# GENIO POPV LI ROMANI
# GENIO POPV LI   ROMANI
# GENIO   POP ROM
# SOLI INVIC TO COMITI
# GENIO POP VLI ROMANI
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
#
# PROVIDENTIA DEORVM QVIES AVGG
# GENIO POP VLI ROMANI
# QVIES   AVGG
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# SACRA MON VRB AVGG ET CAESS NN
# FIDES   M I LITVM
# GENIO   POP ROM
# CONSERV   VRB SVAE
# GENIO POPV LI ROMANI
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO   POP ROM
# MARTI CO NSERVATORI
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO POPV LI ROMANI
# GENIO POPV LI   ROMANI
#  MONETA S AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# CONSERVATO RES VRB SVAE
# GENIO   POP ROM
# SOLI INVIC TO COMITI
# GENIO   POP ROM
# CONSERV   VRB SVAE
# GENIO POPV LI   ROMANI
# SOLI INVIC TO COMITI
# GENIO   POP ROM
# SACRA MONET AVGG ET CAESS NOSTR
# SALVIS AVGG ET CAESS FEL KART
# GENIO POP VLI ROMANI
# GENIO POP V LI ROMANI
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# MEMORIA FELIX
# SAC MON VRB AVGG ET CAESS NN
# SOLI INVIC TO COMITI
# GENIO POPV LI ROMANI
# MONETA S AVGG ET CAESS NN
# SOLI INVIC TO COMITI
# GENIO POPV LI ROMANI
# MARTI PATRI PROPVGNATORI
# SACRA MONET AVGG ET CAESS NOSTR
# MARTI PATRI P ROPVGNATORI
# PROVIDENTIA DEORVM QVIES AVGG
# CONSERVATORES VRB SVAE
# SACRA MONET AVGG   ET CAESS NOSTR
# GENIO POPV L I ROMANI
# GENIO POPV L I ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# MEM DIVI   CONSTANTI
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV LI ROMANI
# FELIX AD V ENT AVGG NN
# GENIO   POP ROM
# CONSERVATORES VRB SVAE
# MARTI CON SERVATORI
# MARTI PATRI PROPVGNATORI
# GENIO POP VLI ROMANI
# GENIO POP VLI ROMANI
# FIDES MI LITVM
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO   POP ROM
# PROVIDENTIA DEORVM QVIES AVGG
# GENIO POP VLI ROMANI
# FELIX AD V ENT AVGG NN
# GENIO POPV LI ROMANI
# GENIO POPV LI   ROMANI
# SALVIS AVGG ET CAESS FEL KART
# MEMORIA FELIX
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# PRINCIPI I VVENTVTIS
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# MARTI PATRI CONSERVATORI
# MEMORIA FELIX
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# PRINCIPI   IVVE NTVTIS
# GENIO POPV LI ROMANI
# FELIX A DV ENT AVGG NN
# MONETA S AVGG ET CAESS NN
# VIRTVS AV GG ET CAESS NN
# GENIO POP VLI ROMANI
# MARTI PATRI PROPVGNATORI
# SOLI INVIC TO COMITI
# SAC MON VRB AVGG ET CAESS NN
# MEMORIA FELIX
# GENIO POPV LI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# VIRTVS AV GG ET CAESS NN
# GENIO POP VLI ROMANI
# FELIX A DV ENT AVGG NN
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO   POP ROM
# SACRA MON VRB AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# GENIO   POP ROM
# CONSERV   VRB SVAE
# FIDES MI LITVM
# SALVIS AVGG ET CAESS FEL KART
# SOLI INVIC TO COMITI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# CONSERV   VRB SVAE
# MARTI PATRI P RO PVGNATORI
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# CONSERV   VRB SVAE
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# SACRA MON VRB AVGG ET CAESS NN
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV L I ROMANI
# SOLI INVIC TO COMITI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# GENIO POP VLI ROMANI
# SAC MON VRB AVGG ET CAESS NN
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# SACRA MON VRB AVGG ET CAESS NN
# VIRTVS AV GG ET CAESS NN
# SACRA MON VRB AVGG ET CAESS NN
# MARTI CON SERVATORI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO   P OP ROM
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# PROVIDENTIA DEORVM QVIES AVGG
#  MONETA S AVGG ET CAESS NN
# GENIO POPV LI ROMANI
# SALVIS AVGG ET CAESS FEL KART
# SOLI INVIC TO COMITI
# SALVIS AVGG ET CAESS FEL KART
# GENIO POPV LI ROMANI
# FIDES   M I LITVM
# PRINCIPI   IVVE NTVTIS
# SACRA MONET AVGG ET CAESS NOSTR
# GENIO POP VLI ROMANI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# GENIO POPV LI ROMANI
# GENIO POPV LI ROMANI
# GENIO   POP ROM
# SOLI INVIC TO COMITI
# CONSERVATO RES VRB SVAE
# GENIO POPV LI ROMANI
# MEMORIA FELIX
# FIDES MI LITVM
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# GENIO POP VLI ROMANI
# GENIO POPV LI ROMANI
# SOLI INVIC TO COMITI
# MARTI PATRI PROP VGNATORI
# GENIO POPV LI ROMANI
# TT
# PLG
# PLG
# PTR
# B
# PTR
# ST
# PTR
# AQP
# Γ
# Δ
# ITR
# PLG
# PLN
# ATR
# AQS
# PLG
# PLG
# PT
# PTR
# B
# PKP
# PLG
# PLG
# ST
# AQP
# TR
# TR
# RQ
# IITR
# TR
# LB
# B
# PTR
# ST
# RQ
# A
# TR
# PT
# PLG
# PTR
# PTR
# PLG
# PTR
# PTR
# PT
# RBT
# ST
# PLG
# ITR
# PTR
# PLG
# TR
# PLG
# PLG
# IITR
# ST
# PLG
# TR
# PTR
# IITR
# IITR
# RT
# PTR
# PLG
# PTR
# XXISIS
# A
# Q
# PTR
# PTR
# PLG
# PLN
# TR
# PLG
# PTR
# PLG
# PT
# Γ
# PLG
# PLG
# BTR
# TR
# PLG
# TR
# PLG
# T
# TR
# PLG
# ST
# ITR
# PLG
# AQS
# ST
# PLG
# PLG
# AQP
# IITR
# PLG
# TR
# PLG
# PT
# Γ
# PLG
# PLG
# ITR
# RP
# PLG
# PLG
# T
# RT
# PKP
# TT
# PKS
# ST
# PLG
# TR
# PTR
# ST
# PTR
# RT
# PLG
# PLG
# BTR
# TR
# TR
# PT
# PLG
# PTR
# PLG
# TR
# IITR
# SIS
# PLG
# PLG
# RP
# PLG
# PLG
# TT
# PLG
# S
# PKP
# TR
# PLG
# PLG
# LP
# PTR
# PTR
# PLN
# ST
# TR
# RP
# PLG
# PLG
# PTR
# ATR
# RT
# ST
# RP
# PLG
# PT
# TT
# B
# PT
# RT
# AQS
# ST
# PLG
# PTR
# AQP
# PLG
# PLG
# TR
# Γ
# TT
# PLG
# PTR
# IITR
# PKQ
# TR
# PTR
# PLG
# TR
# PLG
# PTR
# PLG
# PLG
# PLG
# PLG
# A
# PTR
# RT
# PTR
# LA
# PTR
# A
# Δ
# RP
# PLG
# PLG
# PTR
# PTR
# PLN
# ANT
# PLG
# PTR
# ITR
# PLG
# PTR
# PTR
# TR
# PTR
# PLG
# PTR
# PLG
# PTR
# TR
# PLG
# TT
# A
# PLG
# PLG
# PT
# PTR
# PLG
# PLG
# PTR
# A
# TR
# PT
# HTΔ
# PTR
# ST
# PTR
# T
# PTR
# PTR
# PLG
# TT
# ITR
# PLG
# PTR
# PLG
# PLG
# PTR
# Δ
# TR
# PLG
# Δ
# TT
# A
# PTR
# TT
# TT
# A
# PTR
# PLG
# PTR
# PLG
# PLG
# IITR
# PTR
# AQP
# PT
# PLG
# AQP
# PTR
# ST
# PLG
# B
# PTR
# PLG
# PLG
# SIS
# PTR
# PLG
# PLG
# PT
# PTR
# PLG
# PTR
# PTR
# LON
# TT
# RP
# PLG
# PTR
# PLG
# IITR
# PLG
# PTR
# KΓ
# PTR
# PLN
# PKP
# PLG
# PLG
# ST
# PTR
# IITR
# PTR
# PTR
# ST
# PTR
# PLG
# PTR
# PTR
# PLG
# PLG
# PLG
# B
# TR
# PLG
# T
# PLG
# A
# Δ
# PTR
# TR
# IITR
# PTR
# PTR
# PLG
# PTR
# TT
# PLG
# PLG
# RQ
# ST
# PTR
# p
# PLG
# RQ
# PLG
# B
# PLG
# IITR
# PLG
# PLG
# PTR
# PTR
# RS
# PLG
# PT
# PLN
# PTR
# A
# PLG
# ST
# Γ
# PTR
# TR
# PLG
# PLG
# PTR
# PTR
# PTR
# Δ
# Γ
# Δ
# TR
# TR
# PTR
# PLG
# A
# TR
# RT
# PLG
# PLG
# PTR
# ALE
# B
# PTR
# PT
# PLG
# PT
# PLG
# PLN
# LP
# Δ
# PTR
# PLG
# TT
# PLG
# PT
# T
# IITR
# PTR
# RQ
# PTR
# ST
# PLG
# TT
# PLG
# PTR
# Γ
# RS
# PTR
# PTR
# PLG
# AQS
# PLG
# BTR
# PLG
# PLG
# SIS
# PTR
# PLG
# PTR
# PLG
# PLG
# PTR
# PLG
# PT
# ST
# PLG
# TR
# PLG
# PT
# SIS
# PTR
# B
# PLG
# LP
# RQ
# ST
# PTR
# PTR
# ITR
# PT
# PT
# PLG
# RP
# PTR
# IITR
# PLG
# PLG
# PLG
# PTR
# TR
# Δ
# TR
# ANT
# PTR
# TT
# TR
# Δ
# PLG
# S
# PLG
# PL
# ST
# PLG
# PTR
# PKA
# PLG
# PL
# PT
# ST
# ITR
# p
# PLG
# PTR
# PT
# PLG
# PLG
# p
# PLG
# PLG
# AQГ
# PLG
# PLG
# PL
# RS
# PT
# ST
# PT
# PTR
# ST
# PLG
# PLG
# PTR
# PTR
# PLG
# PLG
# TT
# ATR
# TR
# PTR
# P
# PLG
# ITR
# PTR
# PTR
# PTR
# PLG
# A
# PTR
# PLG
# PT
# PLG
# B
# TR
# PTR
# RQ
# PLG
# PLG
# ST
# ST
# ITR
# PT
# PLG
# TSA
# LA
# B
# ST
# PTR
# ST
# TR
# A
# PTR
# IITR
# ST
# PTR
# PLG
# PLG
# ST
# PLG
# PTR
# PLG
# A
# LP
# PT
# PLG
# PTR
# TT
# Q
# PT
# PTR
# PLG
# RQ
# PLG
# PLG
# PL
# PLG
# AQГ
# PLG
# PLG
# PLG
# PTR
# ϛ
# PLG
# PLG
# PLG
# PLG
# RS
# PLG
# ST
# TR
# PLG
# PT
# PL
# PLG
# PLG
# PLG
# PLG
# PLG
# PLG
# TR
# RQ
# SIS
# PLG
# PTR
# ANT
# RT
# PLG
# PLG
# PLG
# PLG
# TT
# ITR
# ST
# PT
# p
# ITR
# PLG
# PTR
# TR
# PLG
# PTR
# PTR
# PLG
# PLG
# PLG
# PLG
# TT
# PLG
# PLG
# PLG
# PLG
# PT
# TT
# PLG
# Δ
# PTR
# PLG
# PLG
# PTR
# TR
# PLN
# PTR
# PLG
# PT
# IITR
# PT
# PTR
# PLG
# PLG
# PTR
# PLG
# PTR
# TR
# PTR
# S
# TT
# PLG
# ST
# ST
# PLG
# PLG
# PTR
# PLG
# PLG
# PLG
# PTR
# PT
# PLG
# ATR
# H
# TR
# PLG
# RQ
# PLN
# PLG
# PLG
# TT
# IITR
# PLG
# PTR
# ST
# B
# PLG
# PLG
# TT
# PLG
# IITR
# TR
# PLG
# RQ
# PLG
# PLG
# ATR
# PLG
# TR
# PTR
# PT
# PTR
# PLG
# ST
# ST
# PTR
# PTR
# PT
# B
# PT
# PKA
# PLG
# PT
# PTR
# PTR
# PLG
# PLG
# PT
# ST
# PLN
# PTR
# PLG
# PKQ
# PTR
# IITR
# B
# PLN
# PLA
# LA
# PLG
# PLG
# T
# PTR
# PTR
# PLG
# PLG
# PLG
# PLG
# PTR
# p
# PKA
# BTR
# ST
# PLG
# PTR
# PLG
# RP
# PTR
# B
# A
# TT
# PLG
# PKΓ
# ST
# PLG
# P
# TR
# PLG
# PLG
# PT
# TT
# B
# PTR
# PLG
# TR
# PT
# PTR
# PLG
# TR
# PLG
# PT
# ITR
# PTR
# PLG
# T
# PTR
# PTR
# ST
# Γ
# B
# TR
# PLG
# IITR
# TR
# PLG
# PLG
# PLG
# RS
# PLG
# PTR
# ITR
# Q
# TT
# RS
# PTR
# ST
# PTR
# PLG
# AQS
# PLN
# TR
# PTR
# ITR
# Δ
# ATR
# Δ
# PLG
# A
# TR
# ST
# PTR
# TT
# PLG
# PLG
# PTR
# PLG
# TR
# PTR
# PLG
# RP
# ITR
# PLN
# ST
# LA
# PLG
# Q
# PLG
# PTR
# PT

# %% [markdown]
# ___
# ## 4. 1 obverse

# %%
# Show the sample images that we will work on (Need to create a folder to upload sample images in Colab environment)
# 1.obverse image list
img_list_obverse = os.listdir('./toulouse_coins_1_obverse')
img_list_obverse.sort(key=lambda x:int(x.split('toulouse_1_')[1].split('_obverse.jpg')[0]))
#img_list_obverse(uncommenting to see the list of images)


# 2.Create empty dataframe to store output
df_output_obverse = pd.DataFrame(columns = ['img_filename', 'ocr_output'])

#Loop through obverse images
pytesseract.pytesseract.tesseract_cmd = r'D://Users//Tesseract//tesseract.exe'# add the path of your tesseract.exe
custom_config_obverse = r'--oem 0 --psm 6 -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTVXY'# test when psm = 6/7/8/10 respectively
for img in img_list_obverse:
  im = cv2.imread(f'./toulouse_coins_1_obverse/{img}')
  img_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
  output_obverse = pytesseract.image_to_string( img_rgb, lang = 'lat', config=custom_config_obverse ) 
  #output_obverse = pytesseract.image_to_string( img_rgb, lang = 'lat_cus', config=custom_config_obverse) # test with your own language package
  dictionary_obverse = {'img_filename':img, 'ocr_output':str(output_obverse)}
  df_output_obverse = df_output_obverse.append(dictionary_obverse, ignore_index=True)

# 3.Create new columns for reference, CER and WER
#For obverse
df_output_obverse['ref_text'] = ''
df_output_obverse['cer'] = ''
df_output_obverse['wer'] = ''

# Replace new lines in output
df_output_obverse['ocr_output'] = df_output_obverse['ocr_output'].apply(lambda x: x.replace('\n',''))

for i,img in enumerate(img_list_obverse):
    df_output_obverse.loc[df_output_obverse['img_filename'] == img, 'ref_text'] = sheet_monnaies.cell(row = i + 2, column = 4).value

#df_output_obverse(uncommenting to see the results util this step）


# 4. CER and WER for obverse
for index, row in df_output_obverse.iterrows():
  filename = row['img_filename']
  ref = row['ref_text']
  output_obverse = row['ocr_output']
  cer = fastwer.score_sent(output_obverse, ref, char_level=True)
  wer = fastwer.score_sent(output_obverse, ref, char_level=False)
  df_output_obverse.loc[df_output_obverse['img_filename'] == filename, 'cer'] = round(cer,2) # Round value to 2 decimal places
  df_output_obverse.loc[df_output_obverse['img_filename'] == filename, 'wer'] = round(wer,2)

df_output_obverse
# Out:
#                    img_filename  \
# 0      toulouse_1_1_obverse.jpg
# 1      toulouse_1_2_obverse.jpg
# 2      toulouse_1_3_obverse.jpg
# 3      toulouse_1_4_obverse.jpg
# 4      toulouse_1_5_obverse.jpg
# ..                          ...
# 856  toulouse_1_857_obverse.jpg
# 857  toulouse_1_858_obverse.jpg
# 858  toulouse_1_859_obverse.jpg
# 859  toulouse_1_860_obverse.jpg
# 860  toulouse_1_861_obverse.jpg
#
#                                             ocr_output  \
# 0        NR KFETMJT J M VA   T       J JNQ SQKFRQ Q...
# 1    M   N NQTTVFNIVQPVQQMAVQQMVE VDVQ V V VDQVTVV ...
# 2    QN LQQ E QSJNHQ Q Q Q Q VA Q VT EF F AL JQJQLL...
# 3    A S QSF PAPA M APIJNREP KMIMN I A A A I TAMSBQ...
# 4    JLFJ MRVE AFP JQI VINVJFTI II VSVL I L I V J V...
# ..                                                 ...
# 856  QSJ P X S SQ MS FI MSNJSIMFAAQQPTV V C GNIKM I...
# 857  M M MM PM MV V M MMTNPM M A M M M MMMMV MEPTM ...
# 858  VA  M I Q V  V T VIQV I AEPF P NMVV IQ  V N V ...
# 859  JJ  MM P EMP N  II  MF KNINF  TESL   Q VEQL QT...
# 860  MCMMCCM C MVN C C J I CJ H IV  CJLJCJCHQCJ  CQ...
#
#                               ref_text      cer      wer
# 0    D N MAXIMIANO FELICISSIMO SEN AVG   315.15    800.0
# 1                  I MP MAXIMIANVS AVG   694.74    750.0
# 2                  IMP MAXIMIANVS AV G  1736.84   2175.0
# 3                  DIVO CONSTANTIO PIO  1068.42  1866.67
# 4               IMP MAXIMIANVS P F AVG  1004.55   1560.0
# ..                                 ...      ...      ...
# 856          FL VAL CONSTANTINVS NOB C    756.0    940.0
# 857                MAXIMIANVS NOB CAES   2200.0  3633.33
# 858           IMP CONSTANTINVS P F AVG   579.17   1320.0
# 859           IMP CONSTANTINVS P F AVG    325.0    640.0
# 860         IMP C DIOCLETIANVS P F AVG   657.69   783.33
#
# [861 rows x 5 columns]

# %%
# 5. Overall performances for obverse
mean_cer = df_output_obverse['cer'].mean()
mean_wer = df_output_obverse['wer'].mean()
print(f'Mean obverse CER = {mean_cer}%, Mean obverse WER = {mean_wer}%')
# Out:
# Mean obverse CER = 1243.0216027874571%, Mean obverse WER = 1776.291277584203%

# %% [markdown]
# ## 4.2 Reverse

# %%
# 1.reverse image list
img_list_reverse = os.listdir('./toulouse_coins_1_reverse')
img_list_reverse.sort(key=lambda x:int(x.split('toulouse_1_')[1].split('_reverse.jpg')[0]))
#img_list_reverse(uncommenting to see the list of images)

# 2.Create empty dataframe to store output
df_output_reverse = pd.DataFrame(columns = ['img_filename', 'ocr_output'])

#Loop through reverse images
custom_config_reverse = r'--oem 0 --psm 6 -c tessedit_char_whitelist=ABCDEFGHIJKLMNOPQRSTVXY'# test when psm = 6/7/8/10 respectively
for img in img_list_reverse:
  im = cv2.imread(f'./toulouse_coins_1_reverse/{img}')
  img_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
  output_reverse = pytesseract.image_to_string( img_rgb,lang = 'lat', config = custom_config_reverse )
  #output_reverse = pytesseract.image_to_string( img_rgb,lang = 'lat_cus', config = custom_config_reverse)# test with your own language package
  dictionary_reverse = {'img_filename':img, 'ocr_output':str(output_reverse)}
  df_output_reverse = df_output_reverse.append(dictionary_reverse, ignore_index=True)
    
    
# 3.For reverse
df_output_reverse['ref_text'] = ''
df_output_reverse['cer'] = ''
df_output_reverse['wer'] = ''

# Replace new lines in output
df_output_reverse['ocr_output'] = df_output_reverse['ocr_output'].apply(lambda x: x.replace('\n',''))

for i,img in enumerate(img_list_reverse):
    df_output_reverse.loc[df_output_reverse['img_filename'] == img, 'ref_text'] = sheet_monnaies.cell(row = i + 2, column = 7).value

#df_output_reverse（uncommenting to see the results uitl this step）


# 4. CER and WER for reverse
for index, row in df_output_reverse.iterrows():
  filename = row['img_filename']
  ref = row['ref_text']
  output_reverse = row['ocr_output']
  cer = fastwer.score_sent(output_reverse, ref, char_level=True)
  wer = fastwer.score_sent(output_reverse, ref, char_level=False)
  df_output_reverse.loc[df_output_reverse['img_filename'] == filename, 'cer'] = round(cer,2) # Round value to 2 decimal places
  df_output_reverse.loc[df_output_reverse['img_filename'] == filename, 'wer'] = round(wer,2)

df_output_reverse

# %%
# 5.Overall performances for reverse
mean_cer = df_output_reverse['cer'].mean()
mean_wer = df_output_reverse['wer'].mean()
print(f'Mean reverse CER = {mean_cer}%, Mean reverse WER = {mean_wer}%')

# %% [markdown]
# ## 4.3 MintMark

# %%
# 1.mintMark image list
img_list_mintMark = os.listdir('./toulouse_coins_1_mintMark')
img_list_mintMark.sort(key=lambda x:int(x.split('toulouse_1_')[1].split('_mintMark.jpg')[0]))
#img_list_mintMark （uncommenting to see the list of images）

pytesseract.pytesseract.tesseract_cmd = r'D://Users//Tesseract//tesseract.exe'
# 2.Create empty dataframe to store output
df_output_mintMark = pd.DataFrame(columns = ['img_filename', 'ocr_output'])

#Loop through mintMark images

custom_config_mintMark = r'--oem 0 --psm 10 -c tessedit_char_whitelist=ABCDEFGHIKLMNOPQRSTXΔϛЄΓΘ'#test when psm = 6/7/8/10 respectively
for img in img_list_mintMark:
  im = cv2.imread(f'./toulouse_coins_1_mintMark/{img}')
  img_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
  output_mintMark = pytesseract.image_to_string( img_rgb, config=custom_config_mintMark ) #config=custom_config
  #output_mintMark = pytesseract.image_to_string( img_rgb, lang = 'lat_cus', config=custom_config_mintMark )
  dictionary_mintMark = {'img_filename':img, 'ocr_output':str(output_mintMark)}
  df_output_mintMark = df_output_mintMark.append(dictionary_mintMark, ignore_index=True)
    
    
# 3. For mintMark
df_output_mintMark['ref_text'] = ''
df_output_mintMark['cer'] = ''
df_output_mintMark['wer'] = ''

# Replace new lines in output
df_output_mintMark['ocr_output'] = df_output_mintMark['ocr_output'].apply(lambda x: x.replace('\n',''))

for i,img in enumerate(img_list_mintMark):
    df_output_mintMark.loc[df_output_mintMark['img_filename'] == img, 'ref_text'] = mintMark.cell(row = i + 2, column = 1).value

#df_output_mintMark（uncommenting to see the results util this step）


# 4. CER and WER for mintMark
for index, row in df_output_mintMark.iterrows():
  filename = row['img_filename']
  ref = row['ref_text']
  output_mintMark = row['ocr_output']
  cer = fastwer.score_sent(output_mintMark, ref, char_level=True)
  wer = fastwer.score_sent(output_mintMark, ref, char_level=False)
  df_output_mintMark.loc[df_output_mintMark['img_filename'] == filename, 'cer'] = round(cer,2) # Round value to 2 decimal places
  df_output_mintMark.loc[df_output_mintMark['img_filename'] == filename, 'wer'] = round(wer,2)

df_output_mintMark
# Out:
#                     img_filename ocr_output ref_text    cer    wer
# 0      toulouse_1_1_mintMark.jpg
#        TT  100.0  100.0
# 1      toulouse_1_2_mintMark.jpg         M
#       PLG  100.0  100.0
# 2      toulouse_1_3_mintMark.jpg
#       PLG  100.0  100.0
# 3      toulouse_1_4_mintMark.jpg         M
#       PTR  100.0  100.0
# 4      toulouse_1_5_mintMark.jpg         M
#         B  200.0  100.0
# ..                           ...        ...      ...    ...    ...
# 789  toulouse_1_857_mintMark.jpg
#       PLG  100.0  100.0
# 790  toulouse_1_858_mintMark.jpg
#         Q  100.0  100.0
# 791  toulouse_1_859_mintMark.jpg
#       PLG  100.0  100.0
# 792  toulouse_1_860_mintMark.jpg
#       PTR  100.0  100.0
# 793  toulouse_1_861_mintMark.jpg
#        PT  100.0  100.0
#
# [794 rows x 5 columns]

# %%
# 5. Overall performances for mintMark
mean_cer = df_output_mintMark['cer'].mean()
mean_wer = df_output_mintMark['wer'].mean()
print(f'Mean mintMark CER = {mean_cer}%, Mean mintMark WER = {mean_wer}%')
# Out:
# Mean mintMark CER = 103.31654911838791%, Mean mintMark WER = 100.0%
